# %% [markdown]
# # Environment Setup

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
import warnings
warnings.filterwarnings("ignore")

import torch
import os, random
import numpy as np
from tqdm import tqdm

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

seed = 10

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

import pandas as pd

from transformers import AutoTokenizer

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # 1a. ADE Detection

# %% [markdown]
# ### Load ADE detection model

# %%
ade_model = torch.load("Adaptive_Learner/whole_model.pt")
ade_tokenizer = AutoTokenizer.from_pretrained("Adaptive_Learner")

# %% [markdown]
# ### Load Validation Data

# %%
tweets = pd.read_csv("data/smm4h_22/Task1-DataForParticipants/Task1a/valid/tweets.tsv", sep="\t", header=None)
labels = pd.read_csv("data/smm4h_22/Task1-DataForParticipants/Task1a/valid/class.tsv", sep="\t", header=None)

# %%
valid_tweets = list(tweets[1])
valid_tweet_ids = list(tweets[0])

ade_tweet_ids = list(labels[0])

labels = list()

for ids in valid_tweet_ids:
    
    if ids in ade_tweet_ids:
        labels.append("ADE")
    else:
        labels.append("NoADE")

        
tweets["target"] = labels

# %%
tweets.columns = ["tweet_id", "tweet", "target"]

# %%
tweets
# Out:
#                       tweet_id  \
# 0    SMM4H2022ykI8vN7jZYnV57AM
# 1    SMM4H2022uCZV2SRsCe4vzjFm
# 2    SMM4H20229Aha6m4XERqYdFWf
# 3    SMM4H2022UAvDTQWOIacvBkzp
# 4    SMM4H2022qNHntuJnkevkahGr
# ..                         ...
# 904  SMM4H2022CgATBD494ehjw7Aj
# 905  SMM4H2022bRdYe0JKrY3chH6g
# 906  SMM4H2022BNvpfxDmxQy7BPsu
# 907  SMM4H20224d7PvtBV42vXzUgw
# 908  SMM4H2022jUbG4VYZSGSV5zUq
#
#                                                  tweet target
# 0    @USER_________ i found the humira to fix all m...    ADE
# 1    @USER__________ have to go to a doc now to see...    ADE
# 2    06.30 day 14 Rivaroxaban diary. Thanks to para...    ADE
# 3    rt @USER_______: my philly dr prescribed me tr...    ADE
# 4    ciprofloxacin: how do you expect to sleep when...    ADE
# ..                                                 ...    ...
# 904  They've used sildenafil to treat hypertension....  NoADE
# 905  @USER______ thx! the lamictal was a lifesaver ...  NoADE
# 906  Researchers to study effectiveness of atorvast...  NoADE
# 907  Oral #bupe Buprenorphine Hemiadipate rapid dos...  NoADE
# 908  @USER__________ well was remicade. now we are ...  NoADE
#
# [909 rows x 3 columns]

# %% [markdown]
# ### Prediction

# %%
valid_tweets = tweets["tweet"]

label_list = ["ADE", "NoADE"]

predicted_labels = list()

for valid_tweet in valid_tweets:
    inputs = ade_tokenizer(valid_tweet, return_tensors="pt")
    inputs = inputs.to("cuda")
    with torch.no_grad():
        score = ade_model(**inputs).to("cpu").tolist()[0]
        index = score.index(max(score))
        final_label = label_list[index]
        predicted_labels.append(final_label)

# %% [markdown]
# ### Performance Report

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(list(tweets["target"]), predicted_labels, target_names=label_list))
# Out:
#               precision    recall  f1-score   support
#
#          ADE       0.71      0.72      0.72        65
#        NoADE       0.98      0.98      0.98       844
#
#     accuracy                           0.96       909
#    macro avg       0.85      0.85      0.85       909
# weighted avg       0.96      0.96      0.96       909

# %% [markdown]
# # 1b. Span Extraction

# %% [markdown]
# ### Load Validation data

# %%
tweets = pd.read_csv('data/smm4h_22/Task1-DataForParticipants/Task1b/valid/tweets.tsv', sep="\t", header=None)
labels = pd.read_csv('data/smm4h_22/Task1-DataForParticipants/Task1b/valid/spans.tsv', sep="\t", header=None)

# %%
span_df = pd.merge(tweets, labels, on=0)

# %%
span_df.columns = ["tweet_id", "tweet", "label", "start", "end", "span"]

# %%
span_df
# Out:
#                      tweet_id  \
# 0   SMM4H2022ykI8vN7jZYnV57AM
# 1   SMM4H2022ykI8vN7jZYnV57AM
# 2   SMM4H2022uCZV2SRsCe4vzjFm
# 3   SMM4H2022uCZV2SRsCe4vzjFm
# 4   SMM4H20229Aha6m4XERqYdFWf
# ..                        ...
# 82  SMM4H2022cjwbGQbnkpVjjJzR
# 83  SMM4H2022lX1A8RVuySkDzAB2
# 84  SMM4H2022qZC2BPG2BW7UC175
# 85  SMM4H20226b5WyZPTAJ7qL3dE
# 86  SMM4H20220LbDv7WiGBW7nQR4
#
#                                                 tweet label  start  end  \
# 0   @USER_________ i found the humira to fix all m...   ADE    119  125
# 1   @USER_________ i found the humira to fix all m...   ADE    126  139
# 2   @USER__________ have to go to a doc now to see...   ADE     61   68
# 3   @USER__________ have to go to a doc now to see...   ADE     91  110
# 4   06.30 day 14 Rivaroxaban diary. Thanks to para...   ADE    118  134
# ..                                                ...   ...    ...  ...
# 82      Fucking Vyvanse, giving me cotton mouth. UGH.   ADE     27   39
# 83  between the fucking redbull and vyvanse i popp...   ADE     84  104
# 84  rt @USER_______: vyvanse, commonly known as oc...   ADE     45   48
# 85  rt @USER_______: @USE when are you going to do...   ADE     63   71
# 86  I might have gained 30 lbs in 6 weeks on Zypre...   ADE     13   26
#
#                     span
# 0                 nerves
# 1          muscle spasms
# 2                gaining
# 3    gain like 50 pounds
# 4       frontal headache
# ..                   ...
# 82          cotton mouth
# 83  couldn't fall asleep
# 84                   OCD
# 85              addicted
# 86         gained 30 lbs
#
# [87 rows x 6 columns]

# %%
ade_tweets = list(span_df["tweet"])

# %% [markdown]
# ### Load QA model

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, pipeline
model_name = "deepset/roberta-base-squad2"
nlp = pipeline('question-answering', model=model_name, tokenizer=model_name, device=0)
# Out:
# 2022-07-30 08:22:24.202708: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-07-30 08:22:26.397437: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-30 08:22:26.404709: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-30 08:22:26.406246: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-30 08:22:26.408172: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-30 08:22:26.408666: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-30 08:22:26.410188: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-30 08:22:26.411652: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-30 08:22:26.928043: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-30 08:22:26.929665: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-30 08:22:26.931163: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-30 08:22:26.932616: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 12340 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:1e.0, compute capability: 7.5

# %% [markdown]
# ### Prediction

# %%
question = 'What are the side effects?'

qa_spans = list()
span_starts = list()
span_ends = list()
for i in range(0, len(ade_tweets)):
    QA_input = {
    'question': question,
    'context': ade_tweets[i]
    }
    result = nlp(QA_input)
    span = result["answer"]
    start = result["start"]
    end = result["end"]
    qa_spans.append(span)
    span_starts.append(start)
    span_ends.append(end)

# %%
task_1b_df = span_df[["tweet_id", "tweet", "label"]]

# %%
task_1b_df["span"] = qa_spans
task_1b_df["start"] = span_starts
task_1b_df["end"] = span_ends

# %%
task_1b_df
# Out:
#                      tweet_id  \
# 0   SMM4H2022ykI8vN7jZYnV57AM
# 1   SMM4H2022ykI8vN7jZYnV57AM
# 2   SMM4H2022uCZV2SRsCe4vzjFm
# 3   SMM4H2022uCZV2SRsCe4vzjFm
# 4   SMM4H20229Aha6m4XERqYdFWf
# ..                        ...
# 82  SMM4H2022cjwbGQbnkpVjjJzR
# 83  SMM4H2022lX1A8RVuySkDzAB2
# 84  SMM4H2022qZC2BPG2BW7UC175
# 85  SMM4H20226b5WyZPTAJ7qL3dE
# 86  SMM4H20220LbDv7WiGBW7nQR4
#
#                                                 tweet label  \
# 0   @USER_________ i found the humira to fix all m...   ADE
# 1   @USER_________ i found the humira to fix all m...   ADE
# 2   @USER__________ have to go to a doc now to see...   ADE
# 3   @USER__________ have to go to a doc now to see...   ADE
# 4   06.30 day 14 Rivaroxaban diary. Thanks to para...   ADE
# ..                                                ...   ...
# 82      Fucking Vyvanse, giving me cotton mouth. UGH.   ADE
# 83  between the fucking redbull and vyvanse i popp...   ADE
# 84  rt @USER_______: vyvanse, commonly known as oc...   ADE
# 85  rt @USER_______: @USE when are you going to do...   ADE
# 86  I might have gained 30 lbs in 6 weeks on Zypre...   ADE
#
#                                          span  start  end
# 0                        nerves/muscle spasms    118  138
# 1                        nerves/muscle spasms    118  138
# 2                       now i have to lose it    118  139
# 3                       now i have to lose it    118  139
# 4                       frontal headache, 1/2    118  139
# ..                                        ...    ...  ...
# 82                               cotton mouth     27   39
# 83   couldn't fall asleep for the life of me.     84  124
# 84  vyvanse, commonly known as ocd in a pill.     17   58
# 85                                   addicted     63   71
# 86                                    Zyprexa     41   48
#
# [87 rows x 6 columns]

# %% [markdown]
# ### Performance Report

# %%
predicted_label = list(task_1b_df["span"])

original_label = list(span_df["span"])

# %%
labels = list()
for org, pre in zip(original_label, predicted_label):
    
    if org in pre:
        labels.append(str(1))
    else:
        labels.append(str(0))

# %%
gold_labels = ['1']*len(labels)

# %%
label_list = ['0', '1']
print(classification_report(gold_labels, labels, target_names=label_list))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.63      0.77        87
#
#     accuracy                           0.63        87
#    macro avg       0.50      0.32      0.39        87
# weighted avg       1.00      0.63      0.77        87

# %% [markdown]
# # 1.c Normalization

# %%
from fuzzywuzzy import process
import pickle
import re

# %% [markdown]
# ### Load Validation data

# %%
tweets = pd.read_csv('data/smm4h_22/Task1-DataForParticipants/Task1c/valid/tweets.tsv', sep="\t", header=None)
labels = pd.read_csv('data/smm4h_22/Task1-DataForParticipants/Task1c/valid/spans_norm.tsv', sep="\t", header=None)

# %%
norm_df = pd.merge(tweets, labels, on=0)

# %%
norm_df.columns = ["tweet_id", "tweets", "label", "start", "end", "span", "code"]

# %%
norm_df
# Out:
#                      tweet_id  \
# 0   SMM4H2022ykI8vN7jZYnV57AM
# 1   SMM4H2022ykI8vN7jZYnV57AM
# 2   SMM4H2022uCZV2SRsCe4vzjFm
# 3   SMM4H2022uCZV2SRsCe4vzjFm
# 4   SMM4H20229Aha6m4XERqYdFWf
# ..                        ...
# 82  SMM4H2022cjwbGQbnkpVjjJzR
# 83  SMM4H2022lX1A8RVuySkDzAB2
# 84  SMM4H2022qZC2BPG2BW7UC175
# 85  SMM4H20226b5WyZPTAJ7qL3dE
# 86  SMM4H20220LbDv7WiGBW7nQR4
#
#                                                tweets label  start  end  \
# 0   @USER_________ i found the humira to fix all m...   ADE    119  125
# 1   @USER_________ i found the humira to fix all m...   ADE    126  139
# 2   @USER__________ have to go to a doc now to see...   ADE     61   68
# 3   @USER__________ have to go to a doc now to see...   ADE     91  110
# 4   06.30 day 14 Rivaroxaban diary. Thanks to para...   ADE    118  134
# ..                                                ...   ...    ...  ...
# 82      Fucking Vyvanse, giving me cotton mouth. UGH.   ADE     27   39
# 83  between the fucking redbull and vyvanse i popp...   ADE     84  104
# 84  rt @USER_______: vyvanse, commonly known as oc...   ADE     45   48
# 85  rt @USER_______: @USE when are you going to do...   ADE     63   71
# 86  I might have gained 30 lbs in 6 weeks on Zypre...   ADE     13   26
#
#                     span      code
# 0                 nerves  10029177
# 1          muscle spasms  10028334
# 2                gaining  10047896
# 3    gain like 50 pounds  10047896
# 4       frontal headache  10019211
# ..                   ...       ...
# 82          cotton mouth  10013781
# 83  couldn't fall asleep  10044698
# 84                   OCD  10029898
# 85              addicted  10012336
# 86         gained 30 lbs  10047896
#
# [87 rows x 7 columns]

# %% [markdown]
# ### MedDRA dictionary

# %%
read_file = open('VectorizedMedDRA','rb')
object_file = pickle.load(read_file)
read_file.close()

meddra_terms = object_file["med_terms"]

# %% [markdown]
# ### Corpus dictionary

# %%
corpus_df = pd.read_csv("data/smm4h_22/Task1-DataForParticipants/Task1c/train/train_spans_norm.tsv", sep="\t", header=None)

# %%
med_terms = list(corpus_df[4]) 
med_codes = list(corpus_df[5])

# %% [markdown]
# ### Mapping to llt.asc

# %%
final_med_codes = list()

for i, tweet in enumerate(list(norm_df["tweets"])):
    
    tweet = tweet.replace("@USER", " ")
    
    tweet = re.sub(r"[^a-zA-Z0-9 ]", " ", tweet)
    
    tweet = tweet.replace("_", " ")
    
    while "  " in  tweet:
        tweet = tweet.replace("  ", " ")
    
    QA_input = {
    'question': 'What are the side effects?',
    'context': tweet
    }
    result = nlp(QA_input)
    span = result["answer"]
    
    str2Match = span
    strOptions = meddra_terms
    meddra_highest = process.extractOne(str2Match,strOptions)
    
    
    str2Match = span
    strOptions = med_terms
    sm_highest = process.extractOne(str2Match,strOptions)
    
    # selecting based on high score
    if meddra_highest[1] >= sm_highest[1]:
        med_code = object_file["med_ids"][meddra_terms.index(meddra_highest[0])]
    else:
        med_code = med_codes[med_terms.index(sm_highest[0])]
        
    final_med_codes.append(med_code)

# %% [markdown]
# ### Performance Report

# %%
gold_codes = [str(item) for item in list(norm_df["code"])]
predicted_codes = [str(item) for item in final_med_codes]

# %%
print(classification_report(gold_codes, predicted_codes))
# Out:
#               precision    recall  f1-score   support
#
#     10000033       0.00      0.00      0.00         0
#     10000140       0.00      0.00      0.00         0
#     10000194       0.00      0.00      0.00         0
#     10000283       0.00      0.00      0.00         0
#     10000685       0.00      0.00      0.00         0
#     10001125       0.00      0.00      0.00         1
#     10001154       0.00      0.00      0.00         0
#     10001803       0.00      0.00      0.00         0
#     10002855       0.50      1.00      0.67         1
#     10003028       0.00      0.00      0.00         0
#     10003288       0.00      0.00      0.00         0
#     10003543       0.00      0.00      0.00         0
#     10003731       0.00      0.00      0.00         0
#     10003988       1.00      1.00      1.00         1
#     10004063       0.00      0.00      0.00         1
#     10004716       1.00      1.00      1.00         1
#     10004969       0.00      0.00      0.00         0
#     10005613       0.00      0.00      0.00         1
#     10009218       0.00      0.00      0.00         0
#     10009721       0.00      0.00      0.00         0
#     10010300       0.00      0.00      0.00         1
#     10011001       0.00      0.00      0.00         1
#     10011599       0.00      0.00      0.00         0
#     10011865       0.00      0.00      0.00         1
#     10012194       0.00      0.00      0.00         0
#     10012336       0.00      0.00      0.00         1
#     10013573       0.00      0.00      0.00         1
#     10013632       0.00      0.00      0.00         1
#     10013754       0.00      0.00      0.00         2
#     10013767       1.00      1.00      1.00         1
#     10013781       0.00      0.00      0.00         1
#     10013932       0.00      0.00      0.00         1
#     10016167       0.00      0.00      0.00         0
#     10016323       0.00      0.00      0.00         1
#     10016365       1.00      0.50      0.67         2
#     10016370       0.00      0.00      0.00         1
#     10016384       1.00      1.00      1.00         1
#     10016790       0.00      0.00      0.00         0
#     10016791       0.00      0.00      0.00         1
#     10018222       0.00      0.00      0.00         0
#     10018732       0.00      0.00      0.00         1
#     10019136       0.00      0.00      0.00         1
#     10019198       0.25      1.00      0.40         1
#     10019211       0.00      0.00      0.00         1
#     10019299       0.00      0.00      0.00         0
#     10019304       0.00      0.00      0.00         1
#     10021270       0.00      0.00      0.00         0
#     10021654       0.00      0.00      0.00         2
#     10021681       0.00      0.00      0.00         0
#     10022437       0.00      0.00      0.00         0
#     10022989       0.00      0.00      0.00         1
#     10023522       0.00      0.00      0.00         0
#     10026755       0.00      0.00      0.00         0
#     10026865       0.00      0.00      0.00         0
#     10027175       0.00      0.00      0.00         1
#     10027352       0.00      0.00      0.00         1
#     10027374       1.00      0.50      0.67         2
#     10027599       0.00      0.00      0.00         1
#     10028280       0.00      0.00      0.00         0
#     10028333       0.00      0.00      0.00         0
#     10028334       0.00      0.00      0.00         1
#     10028667       0.00      0.00      0.00         0
#     10028813       0.00      0.00      0.00         1
#     10028822       0.00      0.00      0.00         1
#     10029177       0.00      0.00      0.00         1
#     10029898       0.00      0.00      0.00         1
#     10033336       0.00      0.00      0.00         0
#     10033371       1.00      1.00      1.00         1
#     10034100       0.00      0.00      0.00         0
#     10034748       0.00      0.00      0.00         0
#     10035067       0.00      0.00      0.00         1
#     10036661       1.00      1.00      1.00         1
#     10037234       0.00      0.00      0.00         1
#     10037740       0.00      0.00      0.00         0
#     10037844       1.00      1.00      1.00         1
#     10038742       1.00      1.00      1.00         1
#     10038743       0.00      0.00      0.00         1
#     10039769       0.00      0.00      0.00         0
#     10040528       1.00      0.50      0.67         2
#     10040967       0.00      0.00      0.00         0
#     10040995       0.00      0.00      0.00         1
#     10041001       0.00      0.00      0.00         0
#     10041014       0.67      0.67      0.67         3
#     10041017       0.00      0.00      0.00         3
#     10041053       0.00      0.00      0.00         1
#     10041349       0.00      0.00      0.00         2
#     10041374       0.00      0.00      0.00         1
#     10042112       0.00      0.00      0.00         1
#     10042113       0.00      0.00      0.00         1
#     10042494       1.00      0.50      0.67         2
#     10042661       0.50      0.50      0.50         2
#     10044034       0.00      0.00      0.00         1
#     10044698       0.00      0.00      0.00         1
#     10046317       0.00      0.00      0.00         1
#     10047699       0.00      0.00      0.00         0
#     10047700       0.25      1.00      0.40         1
#     10047890       0.00      0.00      0.00         0
#     10047896       0.00      0.00      0.00         8
#     10048010       0.00      0.00      0.00         1
#     10048967       0.00      0.00      0.00         0
#     10050462       0.00      0.00      0.00         1
#     10056484       0.50      1.00      0.67         1
#     10065015       0.00      0.00      0.00         1
#     10065032       0.00      0.00      0.00         1
#     10073281       0.00      0.00      0.00         2
#     10074314       0.00      0.00      0.00         1
#
#     accuracy                           0.22        87
#    macro avg       0.14      0.14      0.13        87
# weighted avg       0.24      0.22      0.21        87
